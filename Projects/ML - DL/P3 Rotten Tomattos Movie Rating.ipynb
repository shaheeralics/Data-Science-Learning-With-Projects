# %% [markdown]
# <div style="background-color:#E6F9E6; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 20px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#4A90E2; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         Movie Reviews Dataset: A Deep Dive into Critic Insights and Sentiment Trends
#     </h1>
# </div>

# %% [markdown]
# <div style="background-color:lightblue; padding: 12px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 12px;">
#     <h1 style="font-size:28px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         Table of Contents:
#     </h1>
# </div>

# %% [markdown]
# <div style="background-color:#E6F9E6; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 20px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#4A90E2; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         About Author
#     </h1>
#     <div style="text-align:center;">
#         <a href="https://www.sak.kesug.com">
#             <img src="https://media.licdn.com/dms/image/v2/D4D03AQEsEJ_gVNnU3w/profile-displayphoto-shrink_200_200/profile-displayphoto-shrink_200_200/0/1720678393429?e=2147483647&v=beta&t=RALfVAKvT6TmP2BBpil_CGzZK5L5ykNUou5yModXTVw" style="width: 20%; border-radius: 50%;" alt="Shaheer Ali">
#         </a>
#     </div>
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333; text-align:center;">Mr. Shaheer Ali</h2>
#     <p style="font-size:16px; font-family:Georgia, serif; line-height: 1.5em; text-align:center; color:#333;">
#         <em>Data Scientist / ML Engineer</em><br>
#         BS Computer Science
#     </p>
#     <div style="text-align:center; margin-top: 10px;">
#         <a href="https://www.youtube.com/channel/UCUTphw52izMNv9W6AOIFGJA">
#             <img width="50" height="50" src="https://img.icons8.com/color/48/youtube-play.png" alt="youtube-play">
#         </a>
#         <a href="https://twitter.com/__shaheerali190">
#             <img width="50" height="50" src="https://img.icons8.com/dotty/80/x.png" alt="x">
#         </a>
#         <a href="https://www.linkedin.com/in/shaheer-ali-2761aa303/">
#             <img width="50" height="50" src="https://img.icons8.com/color/48/linkedin.png" alt="linkedin">
#         </a>
#         <a href="https://github.com/shaheeralics">
#             <img width="50" height="50" src="https://img.icons8.com/ios-glyphs/50/github.png" alt="github">
#         </a>
#         <a href="https://www.kaggle.com/shaheerali197">
#             <img width="50" height="50" src="https://img.icons8.com/clouds/100/kaggle.png" alt="kaggle">
#         </a>
#     </div>
#     <div style="text-align:center; margin-top: 20px;">
#         <a href="https://www.sak.kesug.com" style="font-size:18px; font-family:Georgia, serif; color:#4A90E2; text-decoration:none; border:2px solid #4A90E2; padding: 5px 15px; border-radius: 5px;">
#             Portfolio Site
#         </a>
#     </div>
# </div>

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 12px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 12px;">
#     <h1 style="font-size:28px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         Meta Data
#     </h1>
# </div>
# <div style="background-color:#E6F9E6; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 20px;">
#     <p style="font-size:16px; font-family:Georgia, serif; line-height: 1.5em; text-indent: 20px; color:#333;">
#         This dataset includes 1.44 million rows of movie reviews encompassing critic information, review sentiments, and publication details. The dataset features diverse attributes such as review IDs, creation dates, critic names, review states, publication names, and the full text of reviews. It provides a valuable resource for analyzing movie reviews from various perspectives and is ideal for building sophisticated machine learning models and performing in-depth data analyses.
#     </p>
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#66C2A5;">Columns:</h2>
#     <ul style="font-size:16px; font-family:Georgia, serif; color:#333; line-height: 1.5em;">
#         <li><strong>id:</strong> Unique identifier for each review.</li>
#         <li><strong>stringlengths:</strong> Attribute related to string lengths (details unspecified, possibly for analysis or filtering purposes).</li>
#         <li><strong>reviewId:</strong> Unique identifier for each review (integer).</li>
#         <li><strong>creationDate:</strong> Date when the review was created.</li>
#         <li><strong>criticName:</strong> Name of the critic providing the review.</li>
#         <li><strong>isTopCritic:</strong> Boolean flag indicating if the critic is recognized as a top critic.</li>
#         <li><strong>originalScore:</strong> The original rating score given by the critic (may include null values).</li>
#         <li><strong>reviewState:</strong> Review classification state (e.g., "fresh" or "rotten").</li>
#         <li><strong>publicationName:</strong> Name of the publication where the review was published.</li>
#         <li><strong>reviewText:</strong> Full text of the review.</li>
#         <li><strong>scoreSentiment:</strong> Sentiment associated with the review score (e.g., "POSITIVE" or "NEGATIVE").</li>
#         <li><strong>reviewUrl:</strong> URL linking to the full review.</li>
#     </ul>
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#66C2A5;">How it Can Be Used:</h2>
#     <h3 style="font-size:18px; font-family:Georgia, serif; color:#4A90E2;">Sentiment Analysis:</h3>
#     <ul style="font-size:16px; font-family:Georgia, serif; color:#333;">
#         <li><strong>Sentiment Classification:</strong> Train models to classify the sentiment of reviews into categories such as positive, negative, or neutral based on the text and score.</li>
#         <li><strong>Trend Analysis:</strong> Analyze sentiment trends over time or across different movies to gauge audience reactions and changing opinions.</li>
#     </ul>
#     <h3 style="font-size:18px; font-family:Georgia, serif; color:#4A90E2;">Critic Impact Study:</h3>
#     <ul style="font-size:16px; font-family:Georgia, serif; color:#333;">
#         <li><strong>Top Critic Influence:</strong> Investigate the impact of top critics versus non-top critics on movie ratings and sentiment. Determine if reviews by top critics tend to have different sentiments or scores.</li>
#         <li><strong>Critic Comparison:</strong> Compare and contrast reviews from different critics to identify patterns or biases in their assessments.</li>
#     </ul>
#     <h3 style="font-size:18px; font-family:Georgia, serif; color:#4A90E2;">Review State Prediction:</h3>
#     <ul style="font-size:16px; font-family:Georgia, serif; color:#333;">
#         <li><strong>Classification Models:</strong> Develop machine learning models to predict the review state ("fresh" vs. "rotten") based on the review text and other attributes.</li>
#         <li><strong>State Analysis:</strong> Examine the factors that contribute to a review being classified as "fresh" or "rotten."</li>
#     </ul>
#     <h3 style="font-size:18px; font-family:Georgia, serif; color:#4A90E2;">Publication Analysis:</h3>
#     <ul style="font-size:16px; font-family:Georgia, serif; color:#333;">
#         <li><strong>Publication Sentiment:</strong> Assess how different publications report on movies and their tendency towards positive or negative reviews.</li>
#         <li><strong>Publication Trends:</strong> Explore trends in publication reviews to understand their reporting style or bias.</li>
#     </ul>
#     <h3 style="font-size:18px; font-family:Georgia, serif; color:#4A90E2;">Text Analysis and NLP:</h3>
#     <ul style="font-size:16px; font-family:Georgia, serif; color:#333;">
#         <li><strong>Text Mining:</strong> Perform text mining and natural language processing (NLP) to extract key themes, topics, and sentiments from the review text.</li>
#         <li><strong>Feature Extraction:</strong> Use techniques like Named Entity Recognition (NER) and topic modeling to gain insights from the review content.</li>
#     </ul>
#     <h3 style="font-size:18px; font-family:Georgia, serif; color:#4A90E2;">Predictive Modeling:</h3>
#     <ul style="font-size:16px; font-family:Georgia, serif; color:#333;">
#         <li><strong>Score Prediction:</strong> Build models to predict the review score based on the review text and critic attributes.</li>
#         <li><strong>Review Quality Estimation:</strong> Develop algorithms to estimate the quality or impact of reviews based on historical data and critic profiles.</li>
#     </ul>
#     <h3 style="font-size:18px; font-family:Georgia, serif; color:#4A90E2;">Recommendation Systems:</h3>
#     <ul style="font-size:16px; font-family:Georgia, serif; color:#333;">
#         <li><strong>Movie Recommendations:</strong> Use review sentiments and critic ratings to enhance movie recommendation systems, providing users with personalized movie suggestions based on review data.</li>
#     </ul>
#     <h3 style="font-size:18px; font-family:Georgia, serif; color:#4A90E2;">Market Research and Insights:</h3>
#     <ul style="font-size:16px; font-family:Georgia, serif; color:#333;">
#         <li><strong>Consumer Behavior:</strong> Analyze review data to understand consumer preferences and trends in the movie industry.</li>
#         <li><strong>Marketing Strategies:</strong> Use sentiment insights to inform marketing strategies and campaign effectiveness.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color:#E6F9E6; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 20px;">
#     <h2 style="font-size:22px; font-family:Georgia, serif; color:#4A90E2; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">Purpose</h2>
#     <p style="font-size:16px; font-family:Georgia, serif; line-height: 1.5em; color:#333; text-indent: 20px;">
#         The goal of this project is to build a predictive model that can estimate movie ratings based on critic reviews. By analyzing the dataset of 1.44 million movie reviews, we aim to uncover patterns and relationships between critic sentiments, review attributes, and movie scores. The prediction model will help in understanding the factors that contribute to higher or lower movie ratings and can provide insights into how critics' sentiments translate into numeric ratings.
#     </p>
#     <h2 style="font-size:22px; font-family:Georgia, serif; color:#4A90E2; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">Methodology</h2>
#     <p style="font-size:16px; font-family:Georgia, serif; line-height: 1.5em; color:#333; text-indent: 20px;">
#         The process for building the movie rating prediction model will involve the following steps:
#     </p>
#     <ol style="font-size:16px; font-family:Georgia, serif; color:#333; line-height: 1.5em; text-indent: 20px;">
#         <li><strong>Data Preprocessing:</strong> The dataset will undergo cleaning and preprocessing to remove any missing values, handle null values in the <code>originalScore</code> column, and encode categorical variables like <code>reviewState</code> and <code>isTopCritic</code>.</li>
#         <li><strong>Feature Engineering:</strong> Additional features will be engineered based on the text of the reviews (e.g., sentiment analysis, text length) and critic attributes (e.g., top critic flag).</li>
#         <li><strong>Model Selection:</strong> We will experiment with various machine learning models such as linear regression, decision trees, and random forests, along with advanced algorithms like gradient boosting and neural networks to predict the rating.</li>
#         <li><strong>Model Training and Tuning:</strong> The selected models will be trained on a portion of the dataset, and hyperparameter tuning will be conducted to optimize their performance.</li>
#         <li><strong>Evaluation:</strong> The model will be evaluated on a test set using appropriate metrics like Mean Squared Error (MSE) and R-squared, ensuring the predicted ratings are close to the actual ones.</li>
#         <li><strong>Interpretability:</strong> Insights from the model will be extracted to understand how each feature impacts the final rating predictions.</li>
#     </ol>
# </div>

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 12px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 12px;">
#     <h1 style="font-size:28px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         Importing Libraries
#     </h1>
# </div>

# %%
# Data manipulation and preprocessing
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning models
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Model evaluation
from sklearn.metrics import mean_squared_error, r2_score

# Handling warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 12px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 12px;">
#     <h1 style="font-size:28px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         Loading Dataset
#     </h1>
# </div>

# %%
df= pd.read_csv('../../datasets/Projects/rotten_tomatoes_movie_reviews.csv')

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 12px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 12px;">
#     <h1 style="font-size:28px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         Exploratory Data Analysis
#     </h1>
# </div>

# %%
# showing max columns
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                   id  reviewId creationDate       criticName  \
# 0                            beavers   1145982   2003-05-23  Ivan M. Lincoln
# 1                         blood_mask   1636744   2007-06-02    The Foywonder
# 2  city_hunter_shinjuku_private_eyes   2590987   2019-05-28     Reuben Baron
# 3  city_hunter_shinjuku_private_eyes   2558908   2019-02-14      Matt Schley
# 4                 dangerous_men_2015   2504681   2018-08-29        Pat Padua
#
#    isTopCritic originalScore reviewState                 publicatioName  \
# 0        False         3.5/4       fresh  Deseret News (Salt Lake City)
# 1        False           1/5      rotten                  Dread Central
# 2        False           NaN       fresh                            CBR
# 3        False         2.5/5      rotten                    Japan Times
# 4        False           NaN       fresh                          DCist
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1444963 entries, 0 to 1444962
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   id              1444963 non-null  object
#  1   reviewId        1444963 non-null  int64
#  2   creationDate    1444963 non-null  object
#  3   criticName      1444963 non-null  object
#  4   isTopCritic     1444963 non-null  bool
#  5   originalScore   1009745 non-null  object
#  6   reviewState     1444963 non-null  object
#  7   publicatioName  1444963 non-null  object
#  8   reviewText      1375738 non-null  object
#  9   scoreSentiment  1444963 non-null  object
#  10  reviewUrl       1234038 non-null  object
# dtypes: bool(1), int64(1), object(9)
# memory usage: 111.6+ MB
